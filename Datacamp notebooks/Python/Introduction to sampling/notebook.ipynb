# %% [markdown]
# # Sampling in Python
# Run the hidden code cell below to import the data used in this course.

# %%
# Importing pandas
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# Importing the course arrays
attrition = pd.read_feather("datasets/attrition.feather")
spotify = pd.read_feather("datasets/spotify_2000_2020.feather")
coffee = pd.read_feather("datasets/coffee_ratings_full.feather")

# %% [markdown]
# ## Take Notes
#
# Add notes about the concepts you've learned and code cells with code you want to keep.

# %% [markdown]
# _Add your notes here_

# %%
# Add your code snippets here

# %%
# Sample 1000 rows from spotify_population
spotify_sample = spotify.sample(1000)

# Print the sample
print(spotify_sample)
# Out:
#        acousticness                            artists  ...  valence    year
# 2702       0.000453               ['WWE', 'Motörhead']  ...    0.339  2006.0
# 10301      0.011100                      ['Badflower']  ...    0.326  2019.0
# 39062      0.866000                        ['Beyoncé']  ...    0.101  2016.0
# 21633      0.207000  ['Lupe Fiasco', 'Matthew Santos']  ...    0.472  2007.0
# 16420      0.169000                   ['BROCKHAMPTON']  ...    0.309  2017.0
# ...             ...                                ...  ...      ...     ...
# 24257      0.836000                     ['Luke Bryan']  ...    0.296  2013.0
# 34615      0.000732                  ['Parkway Drive']  ...    0.197  2012.0
# 3968       0.041300             ['Migos', '21 Savage']  ...    0.471  2018.0
# 14488      0.585000                ['Sabrina Claudio']  ...    0.158  2019.0
# 24121      0.146000                    ['Wiz Khalifa']  ...    0.212  2011.0
#
# [1000 rows x 20 columns]

# %%
# Sample 1000 rows from spotify_population
spotify_sample = spotify.sample(n=1000)

# Calculate the mean duration in mins from spotify_population
mean_dur_pop = spotify['duration_minutes'].mean()

# Calculate the mean duration in mins from spotify_sample
mean_dur_samp = spotify_sample['duration_minutes'].mean()

# Print the means
print(mean_dur_pop)
print(mean_dur_samp)
# Out:
# 3.8521519140900073
# 3.866983183333333

# %%
spotify.columns
# Out:
# Index(['acousticness', 'artists', 'danceability', 'duration_ms',
#        'duration_minutes', 'energy', 'explicit', 'id', 'instrumentalness',
#        'key', 'liveness', 'loudness', 'mode', 'name', 'popularity',
#        'release_date', 'speechiness', 'tempo', 'valence', 'year'],
#       dtype='object')

# %%
# Subset the loudness column of spotify_population
loudness_pop = spotify['loudness']

# Sample 100 values of loudness_pop
loudness_samp = loudness_pop.sample(100)

# Print the sample
print(loudness_samp)
# Out:
# 23029   -5.743
# 17244   -3.180
# 30578   -7.309
# 3894    -4.969
# 6085    -5.697
#          ...
# 4074    -5.690
# 33378   -3.801
# 15638   -5.309
# 35449   -6.456
# 25101   -4.890
# Name: loudness, Length: 100, dtype: float64

# %% [markdown]
# __Convenience Sampling__

# %%
# Visualize the distribution of acousticness with a histogram
spotify.hist('acousticness',bins = np.arange(0,1.01,0.01))
plt.show()

# %%
# Visualize the distribution of duration_minutes as a histogram
spotify['duration_minutes'].hist(bins = np.arange(0,15.5,0.5))
plt.show()# Visualize the distribution of duration_minutes as a histogram
spotify['duration_minutes'].hist(bins = np.arange(0,15.5,0.5))
plt.show()

# %% [markdown]
# __Psuedo-random number generation__

# %%
# Generate random numbers from a Uniform(-3, 3)
uniforms = np.random.uniform(low = -3,high = 3,size =5000)

# Print uniforms
print(uniforms)
# Out:
# [ 2.05756769 -2.09515482  2.34834172 ...  0.25190384 -2.9920843
#  -0.94186305]

# %%
# Generate random numbers from a Normal(5, 2)
normals = np.random.normal(loc = 5,scale = 2,size = 5000)

# Print normals
print(normals)
# Out:
# [2.93850422 3.01762188 5.43735664 ... 8.91931765 3.19287342 5.87387485]

# %%
# Generate random numbers from a Uniform(-3, 3)
uniforms = np.random.uniform(low=-3, high=3, size=5000)

# Plot a histogram of uniform values, binwidth 0.25
plt.hist(uniforms,bins  = np.arange(-3,3.25,0.25))
plt.show()

# %%
# Generate random numbers from a Normal(5, 2)
normals = np.random.normal(loc=5, scale=2, size=5000)

# Plot a histogram of normal values, binwidth 0.5
plt.hist(normals,bins  = np.arange(-2,13.5,0.5))
plt.show()

# %% [markdown]
# __Simple random sampling and systematic random sampling__

# %%
# Sample 70 rows using simple random sampling and set the seed
attrition_samp = attrition.sample(70,random_state = 18900217)

# Print the sample
print(attrition_samp)
# Out:
#       Age  Attrition  ... YearsSinceLastPromotion  YearsWithCurrManager
# 1134   35        0.0  ...                      10                     1
# 1150   52        0.0  ...                       0                     0
# 531    33        0.0  ...                       1                     6
# 395    31        0.0  ...                       0                     1
# 392    29        0.0  ...                       1                     3
# ...   ...        ...  ...                     ...                   ...
# 361    27        0.0  ...                       0                     4
# 1180   36        0.0  ...                       6                     7
# 230    26        0.0  ...                       0                     0
# 211    29        0.0  ...                       0                     2
# 890    30        0.0  ...                       0                     7
#
# [70 rows x 31 columns]

# %%
# Set the sample size to 70
sample_size = 70

# Calculate the population size from attrition_pop
pop_size = len(attrition)

# Calculate the interval
interval = pop_size//sample_size
print(interval)
# Out:
# 21

# %%
# Set the sample size to 70
sample_size = 70

# Calculate the population size from attrition_pop
pop_size = len(attrition)

# Calculate the interval
interval = pop_size // sample_size

# Systematically sample 70 rows
attrition_sys_samp = attrition.iloc[::interval]

# Print the sample
print(attrition_sys_samp)
# Out:
#       Age  Attrition  ... YearsSinceLastPromotion  YearsWithCurrManager
# 0      21        0.0  ...                       0                     0
# 21     19        0.0  ...                       0                     0
# 42     45        0.0  ...                       0                     0
# 63     23        0.0  ...                       0                     1
# 84     30        1.0  ...                       0                     0
# ...   ...        ...  ...                     ...                   ...
# 1365   48        0.0  ...                       0                     0
# 1386   48        0.0  ...                       4                     8
# 1407   50        0.0  ...                      13                     8
# 1428   50        0.0  ...                      14                     7
# 1449   52        0.0  ...                      11                     9
#
# [70 rows x 31 columns]

# %%
# Add an index column to attrition_pop
attrition_pop_id = attrition.reset_index()

# Plot YearsAtCompany vs. index for attrition_pop_id
attrition_pop_id.plot(y = 'YearsAtCompany',x = 'index',kind = 'scatter')
plt.show()

# %%
# Shuffle the rows of attrition_pop
attrition_shuffled = attrition.sample(frac = 1)

# Reset the row indexes and create an index column
attrition_shuffled = attrition_shuffled.reset_index()

# Plot YearsAtCompany vs. index for attrition_shuffled
attrition_shuffled.plot(x = 'index',y = 'YearsAtCompany',kind = 'scatter')
plt.show()

# %%
# Shuffle the rows of attrition_pop
attrition_shuffled = attrition.sample(frac = 1)

# Reset the row indexes and create an index column
attrition_shuffled = attrition_shuffled.reset_index(drop = True).reset_index()

# Plot YearsAtCompany vs. index for attrition_shuffled
attrition_shuffled.plot(x = 'index',y = 'YearsAtCompany',kind = 'scatter')
plt.show()

# %% [markdown]
# __Stratified and Weighted random Sampling__

# %%
# Proportion of employees by Education level
education_counts_pop = attrition['Education'].value_counts(normalize = True)

# Print education_counts_pop
print(education_counts_pop)
# Out:
# Bachelor         0.389116
# Master           0.270748
# College          0.191837
# Below_College    0.115646
# Doctor           0.032653
# Name: Education, dtype: float64

# %%
# Proportion of employees by Education level
education_counts_pop = attrition['Education'].value_counts(normalize=True)

# Print education_counts_pop
print(education_counts_pop)

# Proportional stratified sampling for 40% of each Education group
attrition_strat = attrition.groupby('Education').sample(frac = 0.40,random_state = 2022)


# Print the sample
print(attrition_strat)
# Out:
# Bachelor         0.389116
# Master           0.270748
# College          0.191837
# Below_College    0.115646
# Doctor           0.032653
# Name: Education, dtype: float64
#       Age  Attrition  ... YearsSinceLastPromotion  YearsWithCurrManager
# 1191   53        0.0  ...                       8                    10
# 407    29        0.0  ...                       1                     3
# 1233   59        0.0  ...                       1                     3
# 366    37        0.0  ...                       4                     3
# 702    31        0.0  ...                       1                     4
# ...   ...        ...  ...                     ...                   ...
# 733    38        0.0  ...                       9                     9
# 1061   44        0.0  ...                       0                     2
# 1307   41        0.0  ...                      11                     8
# 1060   33        0.0  ...                       0                     0
# 177    29        0.0  ...                       2                     2
#
# [588 rows x 31 columns]

# %%
# Get 30 employees from each Education group
attrition_eq = attrition.groupby('Education')\
	.sample(n=30, random_state=2022)      

# Get the proportions from attrition_eq
education_counts_eq = attrition_eq['Education'].value_counts(normalize = True)

# Print the results
print(education_counts_eq)
# Out:
# Below_College    0.2
# College          0.2
# Bachelor         0.2
# Master           0.2
# Doctor           0.2
# Name: Education, dtype: float64

# %%
# Plot YearsAtCompany from attrition_pop as a histogram
attrition.hist('YearsAtCompany',bins = np.arange(0,41,1))
plt.show()

# %%
# Sample 400 employees weighted by YearsAtCompany
attrition_weight = attrition.sample(n = 400,weights = 'YearsAtCompany' )

# Print the sample
print(attrition_weight)
# Out:
#       Age  Attrition  ... YearsSinceLastPromotion  YearsWithCurrManager
# 1407   50        0.0  ...                      13                     8
# 784    29        0.0  ...                       2                     8
# 501    38        1.0  ...                       1                     4
# 1105   34        0.0  ...                       0                     7
# 1138   35        0.0  ...                       4                    12
# ...   ...        ...  ...                     ...                   ...
# 1058   34        0.0  ...                       4                    11
# 1125   36        0.0  ...                      10                    11
# 1087   36        0.0  ...                       7                     8
# 153    31        1.0  ...                       2                     2
# 924    30        0.0  ...                      10                     8
#
# [400 rows x 31 columns]

# %%
# Plot YearsAtCompany from attrition_weight as a histogram
attrition_weight.hist('YearsAtCompany',bins = np.arange(0,41,1))
plt.show()

# %%
attrition.YearsAtCompany.mean()
# Out:
# 7.0081632653061225

# %%
attrition_weight.YearsAtCompany.mean()
# Out:
# 11.2325

# %% [markdown]
# __Cluster Sampling__

# %%
import random
# Create a list of unique JobRole values
job_roles_pop = list(attrition['JobRole'].unique())

# Randomly sample four JobRole values
job_roles_samp = random.sample(job_roles_pop,k = 4)

# Print the result
print(job_roles_samp)
# Out:
# ['Laboratory_Technician', 'Sales_Executive', 'Healthcare_Representative', 'Manager']

# %%
# Filter for rows where JobRole is in job_roles_samp
jobrole_condition = attrition['JobRole'].isin(job_roles_samp)
attrition_filtered = attrition[jobrole_condition]

# Print the result
print(attrition_filtered)
# Out:
#       Age  Attrition  ... YearsSinceLastPromotion  YearsWithCurrManager
# 2      18        1.0  ...                       0                     0
# 7      18        1.0  ...                       0                     0
# 8      18        0.0  ...                       0                     0
# 11     30        0.0  ...                       0                     0
# 12     22        0.0  ...                       0                     0
# ...   ...        ...  ...                     ...                   ...
# 1464   55        0.0  ...                       4                    13
# 1465   55        0.0  ...                       7                     7
# 1466   58        0.0  ...                      14                    14
# 1467   58        0.0  ...                       1                     8
# 1468   58        1.0  ...                      15                     6
#
# [818 rows x 31 columns]

# %%
# Create a list of unique JobRole values
job_roles_pop = list(attrition['JobRole'].unique())

# Randomly sample four JobRole values
job_roles_samp = random.sample(job_roles_pop, k=4)

# Filter for rows where JobRole is in job_roles_samp
jobrole_condition = attrition['JobRole'].isin(job_roles_samp)
attrition_filtered = attrition[jobrole_condition]

# Remove categories with no rows
attrition_filtered['JobRole'] = attrition_filtered['JobRole'].cat.remove_unused_categories()

# Randomly sample 10 employees from each sampled job role
attrition_clust = attrition_filtered.groupby("JobRole")\
    .sample(n=10, random_state=2022)

# Print the sample
print(attrition_clust)
# Out:
#       Age  Attrition  ... YearsSinceLastPromotion  YearsWithCurrManager
# 1348   44        1.0  ...                       3                     6
# 886    41        0.0  ...                       1                     2
# 983    39        0.0  ...                       3                     6
# 88     27        1.0  ...                       0                     0
# 189    34        0.0  ...                       0                     2
# 160    24        0.0  ...                       2                     1
# 839    46        0.0  ...                       5                     7
# 966    30        0.0  ...                       4                     7
# 162    28        0.0  ...                       2                     2
# 1231   37        0.0  ...                       4                     7
# 1375   44        0.0  ...                       0                     1
# 1462   54        0.0  ...                       4                     7
# 1316   45        0.0  ...                       0                     0
# 1356   48        0.0  ...                       4                     7
# 1387   48        0.0  ...                       2                     1
# 1321   54        0.0  ...                       4                     4
# 1266   50        0.0  ...                       4                     4
# 1330   46        0.0  ...                       4                     9
# 1052   59        0.0  ...                       0                     4
# 1449   52        0.0  ...                      11                     9
# 1439   58        0.0  ...                       1                     5
# 1339   58        0.0  ...                       2                     2
# 1426   49        0.0  ...                       0                     9
# 1415   48        0.0  ...                      12                     9
# 1322   51        0.0  ...                      15                    15
# 1284   40        0.0  ...                       4                     9
# 1149   37        0.0  ...                       6                     8
# 1126   42        0.0  ...                       0                     0
# 1374   46        0.0  ...                       0                     1
# 1050   33        0.0  ...                       3                     7
# 413    33        0.0  ...                       0                     4
# 1293   39        0.0  ...                      11                    10
# 1193   36        0.0  ...                       4                    11
# 653    31        1.0  ...                       1                     2
# 1341   55        0.0  ...                       1                     0
# 432    35        0.0  ...                       0                     4
# 747    35        0.0  ...                       0                     8
# 1191   53        0.0  ...                       8                    10
# 758    31        0.0  ...                       7                     7
# 1018   31        0.0  ...                       1                     7
#
# [40 rows x 31 columns]

# %% [markdown]
# __Relative error of point estimates__

# %%
# calculate the population mean 
mean_attrition_pop = attrition.Attrition.mean()
# Generate a simple random sample of 50 rows, with seed 2022
attrition_srs50 = attrition.sample(n = 50, random_state = 2022)

# Calculate the mean employee attrition in the sample
mean_attrition_srs50 = attrition_srs50.Attrition.mean()

# Calculate the relative error percentage
rel_error_pct50 = 100 * (abs(mean_attrition_pop - mean_attrition_srs50)) / mean_attrition_pop

# Print rel_error_pct50
print(rel_error_pct50)
# Out:
# 62.78481012658227

# %%
# Generate a simple random sample of 50 rows, with seed 2022
attrition_srs100 = attrition.sample(n = 100, random_state = 2022)

# Calculate the mean employee attrition in the sample
mean_attrition_srs100 = attrition_srs100.Attrition.mean()

# Calculate the relative error percentage
rel_error_pct100 = 100 * (abs(mean_attrition_pop - mean_attrition_srs100)) / mean_attrition_pop

# Print rel_error_pct100
print(rel_error_pct100)
# Out:
# 6.962025316455695

# %%
# Create an empty list
mean_attritions = []
# Loop 500 times to create 500 sample means
for i in range(500):
	mean_attritions.append(
    	attrition.sample(n=60)['Attrition'].mean()
	)
  
# Print out the first few entries of the list
print(mean_attritions[0:5])
# Out:
# [0.2, 0.18333333333333332, 0.18333333333333332, 0.21666666666666667, 0.13333333333333333]

# %%
# Create a histogram of the 500 sample means
plt.hist(mean_attritions,bins  = 16)
plt.show()

# %%
# Expand a grid representing 5 8-sided dice
from pandas import expand_grid
dice = expand_grid(
  {'die1': [1, 2, 3, 4, 5, 6,7,8],
   'die2': [1, 2, 3, 4, 5, 6,7,8],
   'die3': [1, 2, 3, 4, 5, 6,7,8],
   'die4': [1, 2, 3, 4, 5, 6,7,8],
   'die5': [1, 2, 3, 4, 5, 6,7,8]
} )



# Print the result
print(dice)
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Input In [35], in <cell line: 2>()
#       1 # Expand a grid representing 5 8-sided dice
# ----> 2 from pandas import expand_grid
#       3 dice = expand_grid(
#       4   {'die1': [1, 2, 3, 4, 5, 6,7,8],
#       5    'die2': [1, 2, 3, 4, 5, 6,7,8],
#    (...)
#       8    'die5': [1, 2, 3, 4, 5, 6,7,8]
#       9 } )
#      13 # Print the result
#
# ImportError: cannot import name 'expand_grid' from 'pandas' (/usr/local/lib/python3.8/dist-packages/pandas/__init__.py)

# %%
# Sample one to eight, five times, with replacement
five_rolls = np.random.choice(list(range(1, 9)), size=5, replace=True)

# Print the mean of five_rolls
print(five_rolls.mean())
# Out:
# 4.0

# %%
# Replicate the sampling code 1000 times
sample_means_1000 = []
for i in range(1000):
    sample_means_1000.append(
  		np.random.choice(list(range(1, 9)), size=5, replace=True).mean()
    )
    
# Print the first 10 entries of the result
print(sample_means_1000[0:10])
# Out:
# [5.4, 5.4, 3.6, 3.0, 5.0, 4.2, 3.2, 3.6, 4.8, 4.2]

# %%
# Draw a histogram of sample_means_1000 with 20 bins
plt.hist(sample_means_1000, bins=20)
plt.show()

# %% [markdown]
# __Introduction to Bootstrapping__

# %%
# Generate 1 bootstrap resample
spotify_1_resample = spotify.sample(frac = 1, replace = True)

# Print the resample
print(spotify_1_resample)
# Out:
#        acousticness                            artists  ...  valence    year
# 33722       0.54600                    ['John Conlee']  ...    0.899  2003.0
# 30093       0.02790                      ['V V Brown']  ...    0.697  2009.0
# 37956       0.72100                           ['Enya']  ...    0.188  2005.0
# 30126       0.05140                     ['Gummy Bear']  ...    0.988  2009.0
# 3458        0.62300                ['Connan Mockasin']  ...    0.265  2013.0
# ...             ...                                ...  ...      ...     ...
# 21864       0.01620                     ['Kanye West']  ...    0.577  2010.0
# 6189        0.21600                       ['Lil Keed']  ...    0.441  2019.0
# 23368       0.05760                       ['Lonestar']  ...    0.671  2004.0
# 1449        0.13500  ['Run The Jewels', 'Gangsta Boo']  ...    0.554  2014.0
# 15332       0.00413                         ['Strafe']  ...    0.393  2006.0
#
# [41656 rows x 20 columns]

# %%
# Generate 1 bootstrap resample
spotify_1_resample = spotify.sample(frac=1, replace=True)

# Calculate of the danceability column of spotify_1_resample
mean_danceability_1 = np.mean(spotify_1_resample['danceability'])

# Print the result
print(mean_danceability_1)
# Out:
# 0.5915901478778568

# %%
# Replicate this 1000 times
mean_danceability_1000 = []
for i in range(1000):
	mean_danceability_1000.append(
        np.mean(spotify_sample.sample(frac=1, replace=True)['danceability'])
	)
  
# Print the result
print(mean_danceability_1000[:5])
# Out:
# [0.5948014, 0.5885547999999999, 0.6015012, 0.5981586, 0.5831573999999999]

# %%
# Draw a histogram of the resample means
plt.hist(mean_danceability_1000)
plt.show()
